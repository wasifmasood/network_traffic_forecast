# %%
### allows to direct changes in the packages to be immidiately visibe in the notebook 
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
sys.path.append(os.getcwd() + '/../..')
sys.path.append(os.getcwd() + '/..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from datetime import datetime
import helper_v1 as helper

from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics
from fbprophet.plot import add_changepoints_to_plot
from matplotlib import pyplot as plt 

import skopt
from skopt.space import Real, Integer, Categorical
import itertools
from skopt import gp_minimize
import gc

from math import sqrt
from sklearn import metrics

# %%
df_data = pd.read_csv('./data/cell/traffic_cells.csv', sep='|', encoding="UTF-8",
                    warn_bad_lines=False, error_bad_lines=False, header=0, index_col=0)
# Out:
# C:\ProgramData\Anaconda3\envs\shared\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df_data.head()
# Out:
#          cell_key                   ds  prb_dl_used_avg           y  \
# 1057716         0  2019-01-02 00:00:00           15.076  853.171461
# 1049620         0  2019-01-02 00:15:00           17.461  993.111915
# 725344          0  2019-01-02 00:30:00            9.163  266.322692
# 1072162         0  2019-01-02 00:45:00           12.535  318.778401
# 1078715         0  2019-01-02 01:00:00           13.531  393.152370
#
#                   rounded_dt
# 1057716  2019-01-02 00:00:00
# 1049620  2019-01-02 00:00:00
# 725344   2019-01-02 00:00:00
# 1072162  2019-01-02 00:00:00
# 1078715  2019-01-02 01:00:00

# %% [markdown]
# #### Lets see how it looks for one cell

# %%
one_cell_only = df_data[df_data.cell_key==0]

# %%
fig = plt.figure(figsize=(20,16))
plt.plot(one_cell_only.ds[0:200], one_cell_only.y[0:200])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ## Lets prepare the data and add additional fields/information/columns

# %% [markdown]
# #### Day of a Week gives importatn insight here since traffic on weekends are higher compared to normal week days therefore, we explicitly specify day of week

# %%
one_cell_only['week_days'] = one_cell_only['ds'].apply(helper.is_weekend)
one_cell_only['week_ends'] = ~one_cell_only['ds'].apply(helper.is_weekend)
# Out:
# <ipython-input-47-1eb0f8a5c078>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_cell_only['week_days'] = one_cell_only['ds'].apply(helper.is_weekend)
# <ipython-input-47-1eb0f8a5c078>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_cell_only['week_ends'] = ~one_cell_only['ds'].apply(helper.is_weekend)

# %%
one_cell_only
# Out:
#          cell_key                   ds  prb_dl_used_avg            y  \
# 1057716         0  2019-01-02 00:00:00        15.076000   853.171461
# 1049620         0  2019-01-02 00:15:00        17.461000   993.111915
# 725344          0  2019-01-02 00:30:00         9.163000   266.322692
# 1072162         0  2019-01-02 00:45:00        12.535000   318.778401
# 1078715         0  2019-01-02 01:00:00        13.531000   393.152370
# ...           ...                  ...              ...          ...
# 174503          0  2019-06-01 22:45:00        18.469999  1317.995885
# 174504          0  2019-06-01 23:00:00        24.007999  1675.121460
# 171710          0  2019-06-01 23:15:00        27.461000  1549.671488
# 167895          0  2019-06-01 23:30:00        22.219999  1088.450272
# 171711          0  2019-06-01 23:45:00        10.254000   283.692622
#
#                   rounded_dt  week_days  week_ends
# 1057716  2019-01-02 00:00:00       True      False
# 1049620  2019-01-02 00:00:00       True      False
# 725344   2019-01-02 00:00:00       True      False
# 1072162  2019-01-02 00:00:00       True      False
# 1078715  2019-01-02 01:00:00       True      False
# ...                      ...        ...        ...
# 174503   2019-06-01 22:00:00      False       True
# 174504   2019-06-01 23:00:00      False       True
# 171710   2019-06-01 23:00:00      False       True
# 167895   2019-06-01 23:00:00      False       True
# 171711   2019-06-01 23:00:00      False       True
#
# [14206 rows x 7 columns]

# %% [markdown]
# #### Traffic patterns are also different on holidays compared to normal working days therefore, the holiday data is also added

# %%
df_holidays = helper.get_national_holidays(year=2019)
df_holidays
# Out:
#                          holiday          ds  lower_window  upper_window
# 0                       New year  2019-01-01             0             1
# 1                       Epiphany  2019-01-06             0             1
# 2                  Easter Monday  2019-04-22             0             1
# 3                  State Holiday  2019-05-01             0             1
# 4             Ascension Thursday  2019-05-30             0             1
# 5                    Whit Monday  2019-06-10             0             1
# 6                 Corpus Christi  2019-06-20             0             1
# 7   Assumption of Mary to Heaven  2019-08-15             0             1
# 8               National Holiday  2019-10-26             0             1
# 9                 All Saints Day  2019-11-01             0             1
# 10         Immaculate Conception  2019-12-08             0             1
# 11                 Christmas Day  2019-12-25             0             1
# 12             St. Stephen's Day  2019-12-26             0             1

# %% [markdown]
# #### Depending upon what series is going on, the network traffic varies alot as well, so it is usefull to add this info. as well, there are many free sites from where such data can be donwloaded

# %%
match_dates = helper.get_matchdates()
conditions = one_cell_only.ds.isin(match_dates.DateTimeAdj)

# %%
#one_cell_only['game_played'] = np.select(conditions, one_cell_only.ds)

# %%
one_cell_only = one_cell_only[['ds', 'prb_dl_used_avg', 'week_days', 'week_ends', 'y']]

# %%
one_cell_only
# Out:
#                           ds  prb_dl_used_avg  week_days  week_ends  \
# 1057716  2019-01-02 00:00:00        15.076000       True      False
# 1049620  2019-01-02 00:15:00        17.461000       True      False
# 725344   2019-01-02 00:30:00         9.163000       True      False
# 1072162  2019-01-02 00:45:00        12.535000       True      False
# 1078715  2019-01-02 01:00:00        13.531000       True      False
# ...                      ...              ...        ...        ...
# 174503   2019-06-01 22:45:00        18.469999      False       True
# 174504   2019-06-01 23:00:00        24.007999      False       True
# 171710   2019-06-01 23:15:00        27.461000      False       True
# 167895   2019-06-01 23:30:00        22.219999      False       True
# 171711   2019-06-01 23:45:00        10.254000      False       True
#
#                    y
# 1057716   853.171461
# 1049620   993.111915
# 725344    266.322692
# 1072162   318.778401
# 1078715   393.152370
# ...              ...
# 174503   1317.995885
# 174504   1675.121460
# 171710   1549.671488
# 167895   1088.450272
# 171711    283.692622
#
# [14206 rows x 5 columns]

# %% [markdown]
# #### Lets seperate train from test. I added last 7 entries (quarters) as test data

# %%
m_prophet = Prophet(daily_seasonality=True, weekly_seasonality=True, holidays = df_holidays)
m_prophet.add_seasonality(name='weekly_days_season', period=7, fourier_order=3, condition_name='week_days')
m_prophet.add_seasonality(name='weekly_ends_season', period=7, fourier_order=3, condition_name='week_ends')
#m_prophet.add_regressor('game_played')
m_prophet.add_regressor('prb_dl_used_avg')

# %%
m_prophet.fit(one_cell_only)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
df_cv = cross_validation(m_prophet, period='18 day', horizon = '3 day')
# Out:
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
df_p = performance_metrics(df_cv)
df_p
# Out:
#             horizon         mse       rmse        mae      mape     mdape  \
# 0   0 days 08:00:00  117.749172  10.851229   6.272793  1.073716  0.856392
# 1   0 days 08:15:00  120.827446  10.992154   6.349467  1.075148  0.849208
# 2   0 days 08:30:00  132.981370  11.531755   6.610557  1.078163  0.849208
# 3   0 days 08:45:00  147.972634  12.164400   6.888271  1.076066  0.850379
# 4   0 days 09:00:00  147.922515  12.162340   6.885818  1.053343  0.842446
# ..              ...         ...        ...        ...       ...       ...
# 252 2 days 23:00:00  405.143710  20.128182  16.685187  0.575635  0.416552
# 253 2 days 23:15:00  413.708871  20.339835  16.851570  0.579588  0.421232
# 254 2 days 23:30:00  406.073863  20.151274  16.534025  0.568489  0.416552
# 255 2 days 23:45:00  401.676262  20.041863  16.410953  0.568611  0.420201
# 256 3 days 00:00:00  398.642340  19.966030  16.294515  0.569977  0.422895
#
#      coverage
# 0    0.950000
# 1    0.945455
# 2    0.940909
# 3    0.936364
# 4    0.936364
# ..        ...
# 252  0.665909
# 253  0.659091
# 254  0.663636
# 255  0.663636
# 256  0.665909
#
# [257 rows x 7 columns]

# %%
np.mean(df_p.rmse)
# Out:
# 14.767219271701892

# %%
np.mean(df_p.mse)
# Out:
# 232.0462698638411

# %% [markdown]
# ### trying forecast

# %%
test_window = 15*24 ### predict next 15*72 quarters, i.e. next three days forecast
max_rows = one_cell_only.shape[0]

df_train = one_cell_only[0:max_rows-test_window]
df_test = one_cell_only[max_rows-test_window:max_rows]
df_train.shape, df_test.shape
# Out:
# ((13846, 5), (360, 5))

# %%
df_X_test = df_test[['ds', 'prb_dl_used_avg', 'week_days','week_ends']]
df_y_test = df_test[['y']]

# %%
df_forecast_w_history = m_prophet.predict(df_X_test)
df_forecast_w_history[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#                      ds        yhat  yhat_lower   yhat_upper
# 0   2019-05-29 06:00:00  178.633143 -163.746065   524.739896
# 1   2019-05-29 06:15:00  247.624602 -115.242360   608.141639
# 2   2019-05-29 06:30:00  237.603281 -113.190704   585.323635
# 3   2019-05-29 06:45:00  450.388806  108.533774   783.452862
# 4   2019-05-29 07:00:00  364.854222    7.804271   693.416792
# ..                  ...         ...         ...          ...
# 355 2019-06-01 22:45:00  706.098128  391.912954  1056.180123
# 356 2019-06-01 23:00:00  872.567419  510.043420  1233.861356
# 357 2019-06-01 23:15:00  975.886919  623.342333  1319.686596
# 358 2019-06-01 23:30:00  823.018119  478.319086  1145.542656
# 359 2019-06-01 23:45:00  471.308702  120.492866   786.905533
#
# [360 rows x 4 columns]

# %%
sqrt(metrics.mean_squared_error(df_y_test.values, df_forecast_w_history.yhat.values))
# Out:
# 282.40176582891354

# %% [markdown]
# ### Lets try some bayesian optimization

# %%
param_grid = [       
    Real(0.001, 0.9,  name='changepoint_prior_scale')
    ,Real(0.001, 10,  name='seasonality_prior_scale')     
    ,Categorical(['multiplicative', 'additive'], name='seasonality_mode')    
    ,Real(0.85, 0.95,  name='changepoint_range') 
]

# %%
def objective(values):
    
    params = {
        'changepoint_prior_scale': values[0]
        ,'seasonality_prior_scale': values[1]
        ,'seasonality_mode': values[2]
        ,'changepoint_range': values[3]
        ,'daily_seasonality': True
        ,'weekly_seasonality': True
    }
    
    m_prophet = Prophet(**params, holidays = df_holidays)
    m_prophet.add_seasonality(name='weekly_days_season', period=7, fourier_order=3, condition_name='week_days')
    m_prophet.add_seasonality(name='weekly_ends_season', period=7, fourier_order=3, condition_name='week_ends')
    m_prophet.add_regressor('game_played')
    
    m_prophet.fit(one_cell_only)
    
    ### lets rely on interal CV method of FBProphet
    df_cv = cross_validation(m_prophet, period='18 day', horizon = '3 day')
    df_p = performance_metrics(df_cv)
    
    cv_rmse = np.mean(df_p.rmse)
    
    print('TRAIN.....', cv_rmse)
        
    gc.collect()
    
    #return  np.mean(train_auc_list)
    return cv_rmse

# %%
res_gp = gp_minimize(objective, param_grid, acq_func="LCB", n_calls=100, random_state=0, n_random_starts=10)
"Best score=%.4f" % res_gp.fun
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 15.61660524043867
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 15.106180793793179
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.356248938649305
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 15.427670858382863
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 16.787939071385516
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 14.66245904181193
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 15.304819219354886
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 15.04917104337681
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.008701813899336
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.407754592065295
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.743747795228973
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 18.461788599544885
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.340952917156374
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.567140143397271
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.948077668125675
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.661899452748525
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.02806733278712
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.332364769628064
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.38469640003026
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 18.234437214454037
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.802591596153407
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.972200833659487
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 14.981982040868767
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 16.41259657060549
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# TRAIN..... 14.338922684889134
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 16.439604936120126
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.762133203548052
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.343358966895282
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.792930272203124
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.729846206549915
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.749950572052121
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.709651830241533
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.340511578368952
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.71653076541674
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.81089977094236
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.350455599510287
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.488396944306599
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.292477369630971
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.312524965618763
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.577265017986015
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.29955787435687
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.005940125943836
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.308496263749108
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.586333513499461
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.312560515115287
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.307402081726211
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.475764501853872
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 15.665146817651484
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.31111378039548
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.35233489922403
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.310503294670182
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.434794566477729
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.322748849561064
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.295490804489715
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.330178923989262
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.748762113043528
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.309203559875852
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.335135678784917
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.316734884409342
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.347424519848435
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.314700656169485
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.331646419182414
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.303362257149406
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.28931224651141
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.367139404529818
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.305820705392371
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.302107570341821
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.336307731560101
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.302504694450112
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.448899225354698
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.30530684818369
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.310970763099307
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.29415967685221
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.356225776637592
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.290179343947553
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.278740003701072
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.286372718012165
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.288438732806151
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.292370133068431
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.27052799502962
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.322009133152452
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.297435044435536
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.287155280316446
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.296567509137036
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.290794435453666
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.261262271106032
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.341637250660625
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.297163641043406
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.304171496952632
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.270688307684496
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.292318956877025
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.278159486569574
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.279803575235304
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.26965642491603
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.264075032911002
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.307843360651564
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.275265950269201
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.27376867842839
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.266355606580962
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# TRAIN..... 14.273707110399839
# 'Best score=14.2613'

# %%
res_gp.fun
# Out:
# 14.261262271106032

# %%
res_gp.x
# Out:
# [0.35429577675045293, 7.705131543015455, 'multiplicative', 0.8552874485190513]

# %% [markdown]
# ### Let's fit the model on the best params

# %%
 #params = {
 #       'changepoint_prior_scale': res_gp.x[0]
 #       ,'seasonality_prior_scale': res_gp.x[1]
 #       ,'seasonality_mode': res_gp.x[2]
 #       ,'changepoint_range': res_gp.x[3]
 #       ,'daily_seasonality': True
 #       ,'weekly_seasonality': True
 #   }
    
params = {
    'changepoint_prior_scale': 0.35429577675045293
    ,'seasonality_prior_scale': 7.705131543015455
    ,'seasonality_mode': 'multiplicative'
    ,'changepoint_range': 0.8552874485190513
    ,'daily_seasonality': True
    ,'weekly_seasonality': True
}

# %%
m_prophet = Prophet(**params, holidays = df_holidays)
m_prophet.add_seasonality(name='weekly_days_season', period=7, fourier_order=3, condition_name='week_days')
m_prophet.add_seasonality(name='weekly_ends_season', period=7, fourier_order=3, condition_name='week_ends')
#m_prophet.add_regressor('game_played')
m_prophet.add_regressor('prb_dl_used_avg')
m_prophet.fit(one_cell_only)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
### lets rely on interal CV method of FBProphet
df_cv = cross_validation(m_prophet, period='18 day', horizon = '3 day')
df_p = performance_metrics(df_cv)
df_p
# Out:
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2019-01-23 23:45:00 and 2019-05-29 23:45:00
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
#             horizon         mse       rmse        mae      mape     mdape  \
# 0   0 days 08:00:00  113.007642  10.630505   5.947629  1.127194  0.746736
# 1   0 days 08:15:00  115.008149  10.724185   5.979473  1.121585  0.734682
# 2   0 days 08:30:00  125.763609  11.214438   6.195242  1.117977  0.736313
# 3   0 days 08:45:00  139.597307  11.815130   6.446484  1.110752  0.726695
# 4   0 days 09:00:00  139.439452  11.808448   6.420114  1.078036  0.698194
# ..              ...         ...        ...        ...       ...       ...
# 252 2 days 23:00:00  391.221707  19.779325  15.616900  0.464079  0.376063
# 253 2 days 23:15:00  394.262998  19.856057  15.671580  0.461173  0.382942
# 254 2 days 23:30:00  384.221002  19.601556  15.333498  0.447225  0.376063
# 255 2 days 23:45:00  377.554917  19.430772  15.109206  0.441179  0.364969
# 256 3 days 00:00:00  371.872771  19.284003  14.888735  0.437863  0.372012
#
#      coverage
# 0    0.945455
# 1    0.940909
# 2    0.936364
# 3    0.931818
# 4    0.931818
# ..        ...
# 252  0.679545
# 253  0.675000
# 254  0.684091
# 255  0.688636
# 256  0.697727
#
# [257 rows x 7 columns]

# %%
np.mean(df_p.rmse)
# Out:
# 14.261262271106032

# %%
np.mean(df_p.mse)
# Out:
# 218.2803725170087

# %% [markdown]
# ### Lets try again after HPO

# %%
df_forecast_w_history = m_prophet.predict(df_X_test)
df_forecast_w_history[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#                       ds        yhat  yhat_lower   yhat_upper
# 0    2019-05-16 23:30:00  581.134469  230.603300   928.195748
# 1    2019-05-16 23:45:00  681.496069  329.488431   995.462532
# 2    2019-05-17 00:00:00  628.408033  273.223004   960.766518
# 3    2019-05-17 00:15:00  567.176563  213.406800   900.336500
# 4    2019-05-17 00:30:00  510.401274  162.577485   856.477731
# ...                  ...         ...         ...          ...
# 1435 2019-06-01 22:45:00  706.098128  349.010339  1059.701017
# 1436 2019-06-01 23:00:00  872.567419  536.593023  1175.997449
# 1437 2019-06-01 23:15:00  975.886919  624.423364  1314.216573
# 1438 2019-06-01 23:30:00  823.018119  477.524167  1181.451965
# 1439 2019-06-01 23:45:00  471.308702  118.882427   815.314722
#
# [1440 rows x 4 columns]

# %%
sqrt(metrics.mean_squared_error(df_y_test.values, df_forecast_w_history.yhat.values))
# Out:
# 282.40176582891354
